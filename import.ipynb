# %%
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
from io import StringIO

# %%
import map as mp

# %%
num=np.reshape(np.arange(533900,533980),(8,10)).T[0:8].T[::-1]
mesh=mp.Map('gsi/tokyo',num).tupleList
mesh=np.where(mesh < -1000, 0,mesh)
# Out:
# gsi/tokyo/FG-GML-5339-27-DEM10B/FG-GML-5339-27-*.xml  is not found

# %%
mesh=mesh-np.min(mesh)
temp = np.power(mesh/np.max(mesh),1/4)*255
plt.imshow(temp,"gray",vmin = 0, vmax = 255)

# %%
np.reshape(np.arange(533900,533980),(8,10)).T[0:8].T[::-1]
# Out:
# array([[533970, 533971, 533972, 533973, 533974, 533975, 533976, 533977],
#        [533960, 533961, 533962, 533963, 533964, 533965, 533966, 533967],
#        [533950, 533951, 533952, 533953, 533954, 533955, 533956, 533957],
#        [533940, 533941, 533942, 533943, 533944, 533945, 533946, 533947],
#        [533930, 533931, 533932, 533933, 533934, 533935, 533936, 533937],
#        [533920, 533921, 533922, 533923, 533924, 533925, 533926, 533927],
#        [533910, 533911, 533912, 533913, 533914, 533915, 533916, 533917],
#        [533900, 533901, 533902, 533903, 533904, 533905, 533906, 533907]])

# %%
# Out:
# -9999.0
